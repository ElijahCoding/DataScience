# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pickle
from matplotlib import style

# %%
data = pd.read_csv('./datasets/student-mat.csv', sep=";")

data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

data.head()
# Out:
#    G1  G2  G3  studytime  failures  absences
# 0   5   6   6          2         0         6
# 1   5   5   6          2         0         4
# 2   7   8  10          2         3        10
# 3  15  14  15          3         0         2
# 4   6  10  10          2         0         4

# %%
predict = 'G3'

X = data.drop([predict], axis=1)
y = np.array(data[predict])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
linear = LinearRegression()

linear.fit(X_train, y_train)

accuracy = linear.score(X_test, y_test)

print('accuracy: \n', accuracy)
print('Coefficient: \n', linear.coef_)
print('Intercept: \n', linear.intercept_)

with open('studentmodel.pickle', 'wb') as f:
    pickle.dump(linear, f)

pickle_in = open('studentmodel.pickle', 'rb')
linear = pickle.load(pickle_in)
# Out:
# accuracy:
#  0.830145406280385
# Coefficient:
#  [ 0.1621295   0.96822821 -0.21325182 -0.35849507  0.04036517]
# Intercept:
#  -1.38878164302675

# %%
predictions = linear.predict(X_test)

# %%
for x in range(len(predictions)):
    print(predictions[x], y_test[x])
# Out:
# -0.9351860403096719 9
# 10.588698596558622 12
# 9.543099000937504 19
# 18.732042046791783 10
# 12.51347098360334 17
# -0.3306789175603777 8
# 18.487068455343376 15
# 11.897869076623516 6
# 11.131558899160945 13
# 14.44135504154305 19
# 11.295639400911314 15
# 11.535040721100723 14
# 8.688328685382665 16
# 13.895383068045735 12
# 10.641915577263852 8
# 5.24915159917189 0
# 9.01595723204995 15
# 6.021182773515354 0
# 4.931867798869735 13
# 8.05389657379308 14
# 5.777805446648692 15
# 4.120812862339396 8
# 8.30109785399111 9
# 11.311209209004192 18
# 12.979015690631398 0
# 18.333666672882224 12
# 4.528952861468439 11
# 14.965385139535615 14
# 9.174698374155708 16
# 9.543099000937504 12
# 9.212358783375228 10
# 10.042726623061307 16
# 11.98175522351902 10
# 12.01941563273854 15
# 7.7870652928324215 8
# 5.827326008546586 12
# 14.505412703766558 14
# 7.293158667589511 5
# -0.7387844889843934 8
# 6.2849865695735225 13
# 3.012667683084018 13
# 9.286832141349201 18
# 6.952404348862196 15
# 4.034813324611137 13
# 8.583151733513391 10
# 10.680270405545881 15
# 5.740377949043563 13
# 15.056956948522872 10
# 12.254743523651028 11
# 9.812242156640284 10
# 8.509808816892383 15
# 12.89612782379813 10
# 10.508271330089364 0
# 11.045326449818294 13
# 9.932408795456789 10
# 8.399322617302863 18
# 11.645442734697742 8
# 14.183356428358275 11
# 7.096757116264232 7
# 6.167263966789865 12
# 8.30109785399111 8
# 16.39052990445653 11
# 9.739500552262783 9
# 12.325986286046446 11
# 16.38495763319753 8
# 15.056956948522872 11
# 10.328239383009835 14
# 8.30109785399111 10
# 14.202186632968035 6
# 15.204786459725023 0
# 16.938496655089068 13
# 12.2926669564093 6
# 7.229233166656732 6
# 10.153128636658327 11
# 15.142956486251132 13
# 8.467757569803016 11
# 11.265897565397943 15
# 15.642584108374935 14
# 12.011382761115527 10
# 14.879385601807355 17
# 9.096384498519207 6
# 7.937355404398579 5
# 10.594270867817624 9
# 8.078299049661842 0
# 3.7117243414355903 11
# 7.485982724791015 10
# 15.234528295238393 12
# 8.400355325070125 8
# 7.517122340976771 0
# 8.387097391719367 14
# 12.368986054910575 12
# 12.860580805411367 8
# 5.970383044642604 0
# 11.664272939307502 16
# 12.962298876854394 10
# 12.777041868047117 17
# 7.440755267177266 11
# 3.73055454604535 13
# 4.360214182528804 15
# 3.794696394261358 11
# 13.50058518825995 9
# 17.15372841102411 13
# 3.9269560973706286 16
# 6.986355102667213 15
# 7.872265034407809 0
# 12.045897071735029 12
# 8.14235671188535 12
# 18.922871326858058 9
# 10.502699058830363 10
# 12.868613677034379 8
# 9.187956307506466 13
# 13.808435008542714 0
# 15.038126743913116 11
# 11.636482532397828 9
# 11.437980826846962 12
# 16.35286949523701 11
# 7.8818974983365635 14
# 13.841471668277995 11
# 8.509724630899882 8
