# %%
import quandl
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = quandl.get('EIA/PET_RWTC_D')

# %%
data.head(), data.tail()
# Out:
# (            Value
#  Date
#  1986-01-02  25.56
#  1986-01-03  26.00
#  1986-01-06  26.53
#  1986-01-07  25.85
#  1986-01-08  25.87,             Value
#  Date
#  2019-12-10  59.22
#  2019-12-11  58.74
#  2019-12-12  59.18
#  2019-12-13  60.11
#  2019-12-16  60.21)

# %%
data.plot(figsize=(12, 6))

# %%
# Change Formats

numpy_data = quandl.get("EIA/PET_RWTC_D", returns="numpy")
numpy_data
# Out:
# rec.array([('1986-01-02T00:00:00.000000000', 25.56),
#            ('1986-01-03T00:00:00.000000000', 26.  ),
#            ('1986-01-06T00:00:00.000000000', 26.53), ...,
#            ('2019-12-12T00:00:00.000000000', 59.18),
#            ('2019-12-13T00:00:00.000000000', 60.11),
#            ('2019-12-16T00:00:00.000000000', 60.21)],
#           dtype=[('Date', '<M8[ns]'), ('Value', '<f8')])

# %%
# Specifying Data

GDP = quandl.get('FRED/GDP', start_date='2001-12-31', end_date="2005-12-31")

# %%
GDP.head()
# Out:
#                 Value
# Date
# 2002-01-01  10788.952
# 2002-04-01  10893.207
# 2002-07-01  10992.051
# 2002-10-01  11071.463
# 2003-01-01  11183.507

# %% [markdown]
# # multiple data

# %%
multi_data = quandl.get(["NSE/OIL.1", "WIKI/AAPL.4"])

# %%
multi_data.head()
# Out:
#             NSE/OIL - Open  WIKI/AAPL - Close
# Date
# 1980-12-12             NaN              28.75
# 1980-12-15             NaN              27.25
# 1980-12-16             NaN              25.25
# 1980-12-17             NaN              25.87
# 1980-12-18             NaN              26.63

# %%
quandl.ApiConfig.api_key = "wa-FxFLJyWvFsyxj6zpA"
quandl.get("FRED/GDP")
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2018-07-01  20749.752
# 2018-10-01  20897.804
# 2019-01-01  21098.827
# 2019-04-01  21340.267
# 2019-07-01  21542.540
#
# [291 rows x 1 columns]

# %% [markdown]
# # FOR STOCKS

# %%
mydata = quandl.get('WIKI/FB',start_date='2015-01-01',end_date='2017-01-01')

# %%
mydata.head()
# Out:
#              Open     High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2015-01-02  78.58  78.9300  77.700  78.450  18177475.0          0.0
# 2015-01-05  77.98  79.2455  76.860  77.190  26452191.0          0.0
# 2015-01-06  77.23  77.5900  75.365  76.150  27399288.0          0.0
# 2015-01-07  76.76  77.3600  75.820  76.150  22045333.0          0.0
# 2015-01-08  76.74  78.2300  76.080  78.175  23960953.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2015-01-02          1.0      78.58    78.9300    77.700      78.450
# 2015-01-05          1.0      77.98    79.2455    76.860      77.190
# 2015-01-06          1.0      77.23    77.5900    75.365      76.150
# 2015-01-07          1.0      76.76    77.3600    75.820      76.150
# 2015-01-08          1.0      76.74    78.2300    76.080      78.175
#
#             Adj. Volume
# Date
# 2015-01-02   18177475.0
# 2015-01-05   26452191.0
# 2015-01-06   27399288.0
# 2015-01-07   22045333.0
# 2015-01-08   23960953.0

# %%
mydata = quandl.get('WIKI/FB.1',start_date='2015-01-01',end_date='2017-01-01')

# %%
mydata.head()
# Out:
#              Open
# Date
# 2015-01-02  78.58
# 2015-01-05  77.98
# 2015-01-06  77.23
# 2015-01-07  76.76
# 2015-01-08  76.74

# %%
mydata = quandl.get('WIKI/FB.7',start_date='2015-01-01',end_date='2017-01-01')

# %%
mydata.head()
# Out:
#             Split Ratio
# Date
# 2015-01-02          1.0
# 2015-01-05          1.0
# 2015-01-06          1.0
# 2015-01-07          1.0
# 2015-01-08          1.0

# %% [markdown]
# ### Housing Price Example

# %%
houses = quandl.get('ZILLOW/M11_ZRIAH')

# %%
houses.head()
# Out:
#               Value
# Date
# 2010-11-30  2450.39
# 2010-12-31  2457.33
# 2011-01-31  2480.48
# 2011-02-28  2502.18
# 2011-03-31  2522.11

# %%
houses.plot()
